# %% [markdown]
# # Crescent Bakery: Summary Statistics
#
# Lesson 1.3 Guided Example. Computes central tendency, position, and
# dispersion on the Crescent Bakery synthetic dataset from Lesson 1.2.
#
# Author: [Kenya Harvey]
# Date: [08/06/2026]

# %%
import pandas as pd
import numpy as np

# %%
bakery = pd.read_csv("../lesson-1-2-types-of-data/bakery_customers.csv")
bakery.head(10)
# Out:
#   customer_id      region  first_visit_year  satisfaction  total_spent_usd  \
# 0  CUST-93810    Downtown              2024             5           351.90
# 1  CUST-24592    West End              2025             5           226.64
# 2  CUST-13278  South Side              2024             5            37.59
# 3  CUST-46048  North Side              2018             5           277.64
# 4  CUST-42098    Downtown              2021             4           218.36
# 5  CUST-39256    Downtown              2022             5           226.87
# 6  CUST-28289    Downtown              2025             2           286.23
# 7  CUST-23434    West End              2021             3           236.72
# 8  CUST-98696  North Side              2023             1           267.20
# 9  CUST-81482  South Side              2022             3            88.21
#
#    visits_last_year
# 0                 9
# 1                11
# 2                 5
# 3                 9
# 4                 8
# ...

# %%
total_spent_mean = bakery["total_spent_usd"].mean()
print(f"Mean total spent: ${total_spent_mean:.2f}")
# Out:
# Mean total spent: $241.71

# %%
total_spent_median = bakery["total_spent_usd"].median()
print(f"Median total spent: ${total_spent_median:.2f}")
# Out:
# Median total spent: $236.93

# %%
total_spent_mode = bakery["total_spent_usd"].mode()
print(f"Mode total spent: {total_spent_mode.values}")
# Out:
# Mode total spent: [ 37.59  88.21 116.12 152.17 158.02 164.2  170.59 174.56 176.82 179.16
#  179.55 185.85 187.97 197.27 204.02 210.53 215.39 216.28 218.36 218.94
#  220.76 226.64 226.87 229.28 236.72 237.13 248.52 249.41 250.31 250.73
#  256.15 258.19 267.2  277.19 277.64 286.23 288.22 292.91 299.64 301.93
#  311.38 311.85 319.89 323.85 351.9  360.72 361.39 362.32 362.42 386.53]

# %%
satisfaction_mode = bakery["satisfaction"].mode()
print(f"Mode satisfaction: {satisfaction_mode.values}")
# Out:
# Mode satisfaction: [5]

# %%
satisfaction_median = bakery["satisfaction"].median()
print(f"Median satisfaction: {satisfaction_median}")
# Out:
# Median satisfaction: 4.0

# %%
satisfaction_mean = bakery["satisfaction"].mean()
print(f"Mean satisfaction: {satisfaction_mean:.2f}")
print("(Mean is technically a category error on ordinal data; use with care.)")
# Out:
# Mean satisfaction: 3.72
# (Mean is technically a category error on ordinal data; use with care.)

# %%
region_mode = bakery["region"].mode()
print(f"Most common region: {region_mode.values[0]}")
# Out:
# Most common region: Downtown

# %%
spent_min = bakery["total_spent_usd"].min()
spent_max = bakery["total_spent_usd"].max()
spent_range = spent_max - spent_min
spent_variance = bakery["total_spent_usd"].var()
spent_std = bakery["total_spent_usd"].std()

print(f"Min: ${spent_min:.2f}")
print(f"Max: ${spent_max:.2f}")
print(f"Range: ${spent_range:.2f}")
print(f"Variance: ${spent_variance:.2f} (squared dollars)")
print(f"Standard deviation: ${spent_std:.2f}")
# Out:
# Min: $37.59
# Max: $386.53
# Range: $348.94
# Variance: $5479.40 (squared dollars)
# Standard deviation: $74.02

# %%
spent_q1 = bakery["total_spent_usd"].quantile(0.25)
spent_q3 = bakery["total_spent_usd"].quantile(0.75)
spent_iqr = spent_q3 - spent_q1

print(f"Q1 (25th percentile): ${spent_q1:.2f}")
print(f"Q3 (75th percentile): ${spent_q3:.2f}")
print(f"IQR: ${spent_iqr:.2f}")
# Out:
# Q1 (25th percentile): $190.30
# Q3 (75th percentile): $291.74
# IQR: $101.44

# %%
spent_p90 = bakery["total_spent_usd"].quantile(0.90)
spent_p95 = bakery["total_spent_usd"].quantile(0.95)
spent_p99 = bakery["total_spent_usd"].quantile(0.99)

print(f"90th percentile: ${spent_p90:.2f}")
print(f"95th percentile: ${spent_p95:.2f}")
print(f"99th percentile: ${spent_p99:.2f}")
# Out:
# 90th percentile: $352.78
# 95th percentile: $361.90
# 99th percentile: $374.72

# %%
bakery["total_spent_usd"].describe()
# Out:
# count     50.000000
# mean     241.710400
# std       74.022959
# min       37.590000
# 25%      190.295000
# 50%      236.925000
# 75%      291.737500
# max      386.530000
# Name: total_spent_usd, dtype: float64

# %%
bakery.describe()
# Out:
#        first_visit_year  satisfaction  total_spent_usd  visits_last_year
# count         50.000000     50.000000        50.000000         50.000000
# mean        2021.640000      3.720000       241.710400          7.960000
# std            2.126221      1.294257        74.022959          2.913445
# min         2018.000000      1.000000        37.590000          2.000000
# 25%         2020.000000      3.000000       190.295000          6.000000
# 50%         2022.000000      4.000000       236.925000          8.000000
# 75%         2023.000000      5.000000       291.737500          9.000000
# max         2025.000000      5.000000       386.530000         15.000000

# %%
bakery.describe(include='object')
# Out:
# /var/folders/ql/lmx1cprj1l1cjx478ft3c9840000gn/T/ipykernel_8834/4188407785.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   bakery.describe(include='object')
#        customer_id    region
# count           50        50
# unique          50         4
# top     CUST-93810  Downtown
# freq             1        24

# %%
import sys
import pandas as pd

try:
    import plotly.express as px
except ModuleNotFoundError:
    # !{sys.executable} -m pip install plotly
    import plotly.express as px

if 'bakery' not in globals():
    try:
        import plotly.express as px
    except ModuleNotFoundError:
        # !{sys.executable} -m pip install plotly
        import plotly.express as px

    if 'bakery' not in globals():
        bakery = pd.read_csv("../lesson-1-2-types-of-data/bakery_customers.csv")

    fig = px.histogram(
        bakery,
        x="total_spent_usd",
        nbins=15,
        title="Distribution of Total Spent (USD)",
    )
    fig.show()
    fig.show()

fig = px.histogram(
    bakery,
    x="total_spent_usd",
    nbins=15,
    title="Distribution of Total Spent (USD)",
)
fig.show()
fig.show()

# %% [markdown]
# The histogram helps analyze the distribution of customer spending.
#
# It can be used to identify:
#
# The most common spending range.
#
# Whether most customers spend relatively small or large amounts.
#
# Whether the data is evenly distributed or skewed.
#
# Possible outliers or unusually high-spending customers.
#
# Whether customer spending appears to form multiple groups.
#
# For example, if most bars are concentrated on the left side of the chart, most customers likely spent smaller amounts. If the chart extends far to the right, the data may be right-skewed because a smaller number of customers spent significantly more.
